# %% [markdown]
# # imports

# %% [markdown]
# # create a contact

# %%
name = "moussa"
number = 01501844888
email = "ahmedmoussa.dev@gmail.com"

# %% [markdown]
# # add contact to contact list

# %% [markdown]
# # - use classes

# %%
class customer:
  name = name
  number = number
  email = email

customer david = name,number,email

# %% [markdown]
#
#   # - use list
#
#   # - use dictionary
#
#   # - use pandas

# %% [markdown]
# # inventory management system

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Statistics

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # linear algebra

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # calculus and trig

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Probability

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Project based learning
# - Research
# - code one time a day

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Numpy
# # Scipy

# %% [markdown]
# # RANDOM GOOGLE ARTICLES

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Other
# ![image.png](attachment:image.png)

# %% [markdown]
# # SQL
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # MAKE A Community

# %% [markdown]
# ![Screenshot 2024-10-20 184928.png](<attachment:Screenshot 2024-10-20 184928.png>)

# %% [markdown]
# # Vlog & Post linkedin, twitter & social media in general

# %% [markdown]
# # Keep up with the industry

# %% [markdown]
# https://youtu.be/UZ1A6eSKE2o

# %% [markdown]
# tier 4 data science projects

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
emoji = {1 : 1 , 2:2}
emoji.get()
